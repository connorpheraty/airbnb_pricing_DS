# %%
ls
# Out:
# Untitled.ipynb          listings.csv            reviews 2.csv
# calendar.csv            neighbourhoods.csv      reviews.csv
# listings 2.csv          neighbourhoods.geojson

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
calendar = pd.read_csv('calendar.csv')
reviews_1 = pd.read_csv('reviews.csv')
reviews_2 = pd.read_csv('reviews_2.csv')
listings = pd.read_csv('listings.csv')
listings_2 = pd.read_csv('listings_2.csv')
neighborhoods = pd.read_csv('neighbourhoods.csv')

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
calendar.shape, reviews_1.shape, reviews_2.shape, listings.shape, listings_2.shape, neighborhoods.shape
# Out:
# ((2981670, 7), (306085, 2), (306085, 6), (8169, 16), (8169, 106), (77, 2))

# %%
calendar.head(100)
# Out:
#     listing_id        date available   price adjusted_price  minimum_nights  \
# 0      1313847  2019-05-19         t  $60.00         $60.00              32
# 1         2384  2019-05-19         f  $70.00         $70.00               2
# 2         2384  2019-05-20         f  $70.00         $70.00               2
# 3         2384  2019-05-21         f  $70.00         $70.00               2
# 4         2384  2019-05-22         f  $70.00         $70.00               2
# 5         2384  2019-05-23         f  $70.00         $70.00               2
# 6         2384  2019-05-24         f  $70.00         $70.00               2
# 7         2384  2019-05-25         f  $70.00         $70.00               2
# 8         2384  2019-05-26         f  $70.00         $70.00               2
# 9         2384  2019-05-27         f  $70.00         $70.00               2
# 10        2384  2019-05-28         t  $70.00         $70.00               2
# 11        2384  2019-05-29         t  $70.00         $70.00               2
# 12        2384  2019-05-30         t  $70.00         $70.00               2
# 13        2384  2019-05-31         t  $70.00         $70.00               2
# 14        2384  2019-06-01         f  $75.00         $75.00               2
# 15        2384  2019-06-02         f  $75.00         $75.00               2
# 16        2384  2019-06-03         t  $75.00         $75.00               2
# 17        2384  2019-06-04         t  $75.00         $75.00               2
# 18        2384  2019-06-05         t  $75.00         $75.00               2
# 19        2384  2019-06-06         t  $75.00         $75.00               2
# 20        2384  2019-06-07         f  $75.00         $75.00               2
# 21        2384  2019-06-08         f  $75.00         $75.00               2
# 22        2384  2019-06-09         t  $75.00         $75.00               2
# 23        2384  2019-06-10         t  $75.00         $75.00               2
# 24        2384  2019-06-11         t  $75.00         $75.00               2
# 25        2384  2019-06-12         t  $75.00         $75.00               2
# 26        2384  2019-06-13         t  $75.00         $75.00               2
# 27        2384  2019-06-14         f  $75.00         $75.00               2
# 28        2384  2019-06-15         f  $75.00         $75.00               2
# 29        2384  2019-06-16         t  $75.00         $75.00               2
# 30        2384  2019-06-17         t  $75.00         $75.00               2
# 31        2384  2019-06-18         t  $75.00         $75.00               2
# 32        2384  2019-06-19         t  $75.00         $75.00               2
# 33        2384  2019-06-20         t  $75.00         $75.00               2
# 34        2384  2019-06-21         t  $75.00         $75.00               2
# 35        2384  2019-06-22         t  $75.00         $75.00               2
# 36        2384  2019-06-23         t  $75.00         $75.00               2
# 37        2384  2019-06-24         t  $75.00         $75.00               2
# 38        2384  2019-06-25         t  $75.00         $75.00               2
# 39        2384  2019-06-26         t  $75.00         $75.00               2
# 40        2384  2019-06-27         f  $70.00         $70.00               2
# 41        2384  2019-06-28         f  $70.00         $70.00               2
# 97        2384  2019-08-23         t  $75.00         $75.00               2
# 98        2384  2019-08-24         t  $75.00         $75.00               2
# 99        2384  2019-08-25         t  $75.00         $75.00               2
#
#     maximum_nights
# 0             1125
# 1               89
# 2               89
# 3               89
# 4               89
# 5               89
# 6               89
# 7               89
# 8               89
# 9               89
# 10              89
# 11              89
# 12              89
# 13              89
# 14              89
# 15              89
# 16              89
# 17              89
# 18              89
# 19              89
# 20              89
# 21              89
# 22              89
# 23              89
# 24              89
# 25              89
# 26              89
# 27              89
# 28              89
# 29              89
# 30              89
# 31              89
# 32              89
# 33              89
# 34              89
# 35              89
# 36              89
# 37              89
# 38              89
# 39              89
# 40              89
# 41              89
# 42              89
# 43              89
# 44              89
# 45              89
# 46              89
# 47              89
# 48              89
# 49              89
# 50              89
# 51              89
# 52              89
# 53              89
# 54              89
# 55              89
# 56              89
# 57              89
# 58              89
# 59              89
# 60              89
# 61              89
# 62              89
# 63              89
# 64              89
# 65              89
# 66              89
# 67              89
# 68              89
# 69              89
# 70              89
# 71              89
# 72              89
# 73              89
# 74              89
# 75              89
# 76              89
# 77              89
# 78              89
# 79              89
# 80              89
# 81              89
# 82              89
# 83              89
# 84              89
# 85              89
# 86              89
# 87              89
# 88              89
# 89              89
# 90              89
# 91              89
# 92              89
# 93              89
# 94              89
# 95              89
# 96              89
# 97              89
# 98              89
# 99              89

# %%
calendar['listing_id'].nunique()
# Out:
# 8169

# %%
reviews_1.head()
# Out:
#    listing_id        date
# 0        2384  2015-01-09
# 1        2384  2015-03-24
# 2        2384  2015-04-19
# 3        2384  2015-04-30
# 4        2384  2015-05-04

# %%
reviews_2.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        2384  25218143  2015-01-09     14385014          Ivan
# 1        2384  28475392  2015-03-24     16241178     Namhaitou
# 2        2384  30273263  2015-04-19     26101401       Patrick
# 3        2384  30974202  2015-04-30     26247321      Cristina
# 4        2384  31363208  2015-05-04     31293837        SuJung
#
#                                             comments
# 0  it's a wonderful trip experience. I didn't exc...
# 1  This is my first trip using Airbnb. I was a li...
# 2  The reservation was canceled 80 days before ar...
# 3  Sólo puedo decir cosas buenas de Rebecca. La h...
# 4  Rebecca was an absolutely wonderful host.\r\n\...

# %%
listings.head()
# Out:
#       id                                               name  host_id  \
# 0   2384  Hyde Park - Walk to UChicago/Metra to McCormic...     2613
# 1   4505         We're back. 365 Great Reviews.  1 bad one.     5775
# 2   7126                Tiny Studio Apartment 94 Walk Score    17928
# 3   9811                      Barbara's Hideaway - Old Town    33004
# 4  10610                   3 Comforts of Cooperative Living     2140
#
#           host_name  neighbourhood_group   neighbourhood  latitude  longitude  \
# 0           Rebecca                  NaN       Hyde Park  41.78886  -87.58671
# 1  Craig & Kathleen                  NaN  South Lawndale  41.85495  -87.69696
# 2             Sarah                  NaN       West Town  41.90289  -87.68182
# 3       At Home Inn                  NaN    Lincoln Park  41.91769  -87.63788
# 4       Lois And Ed                  NaN       Hyde Park  41.79708  -87.59195
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     50               2                149  2019-05-17
# 1  Entire home/apt    117               2                368  2019-05-05
# 2  Entire home/apt     80               2                338  2019-05-05
# 3  Entire home/apt    150               4                 35  2019-05-15
# 4     Private room     35               2                 38  2019-04-12
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               2.81                               1               316
# 1               2.96                               1               310
# 2               2.81                               1               309
# 3               0.56                              11               280
# 4               0.68                               5               240

# %%
listings_2.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2384   https://www.airbnb.com/rooms/2384  20190519023000   2019-05-19
# 1   4505   https://www.airbnb.com/rooms/4505  20190519023000   2019-05-19
# 2   7126   https://www.airbnb.com/rooms/7126  20190519023000   2019-05-19
# 3   9811   https://www.airbnb.com/rooms/9811  20190519023000   2019-05-19
# 4  10610  https://www.airbnb.com/rooms/10610  20190519023000   2019-05-19
#
#                                                 name  \
# 0  Hyde Park - Walk to UChicago/Metra to McCormic...
# 1         We're back. 365 Great Reviews.  1 bad one.
# 2                Tiny Studio Apartment 94 Walk Score
# 3                      Barbara's Hideaway - Old Town
# 4                   3 Comforts of Cooperative Living
#
#                                              summary  \
# 0  Be the sole guest in a quiet, vintage, 2nd flo...
# 1  We took the winter off, made things nicer arou...
# 2   A very small studio in a wonderful neighborhood.
# 3  One-bedroom hideaway tucked into Old Town step...
# 4  The condo is the 2nd floor in a lovely 1912 3-...
#
#                                                space  \
# 0  The private bedroom has a queen size bed, ches...
# 1  We travel a lot, we know what people need.  We...
# 2  This is a very small  studio apartment with a ...
# 3  This lovely one bedroom "hideaway" is located ...
# 4  Newly furnished with queen bed and the comfort...
#
#                                          description experiences_offered  \
# 0  Be the sole guest in a quiet, vintage, 2nd flo...                none
# 1  We took the winter off, made things nicer arou...                none
# 2  A very small studio in a wonderful neighborhoo...                none
# 3  One-bedroom hideaway tucked into Old Town step...                none
# 4  The condo is the 2nd floor in a lovely 1912 3-...                none
#
#                                neighborhood_overview  \
# 0  My apartment is located one block from beautif...
# 1                                                NaN
# 2  Ukrainian Village was just named "Hottest Neig...
# 3  Chicago’s Old Town neighborhood is squeezed be...
# 4  It's a 10 minute walk from the lakefront bike ...
#
#                                                notes  \
# 0  The basement laundry room hours are 8:00am to ...
# 1                                                NaN
# 2  We really like our neighbors and want guests t...
# 3  Vacation rental tax of 21.4 required in additi...
# 4  If you stay longer than 21 days you are expect...
#
#                                              transit  \
# 0  UNIVERSITY OF CHICAGO: Visiting academics and ...
# 1  The CTA train station is 30 yards (27 meters) ...
# 2  We are 1/2 mile away from the el train stop (b...
# 3  Public transit in Chicago is excellent, and al...
# 4  It is a short walk to public transportation th...
#
#                                               access  \
# 0  You will have access to the entire apartment (...
# 1  We also have a huge yard. Use it (weather perm...
# 2  You will be in your own private, tiny apartmen...
# 3                                                NaN
# 4  Pantry has non-perishable food for use by hous...
#
#                                          interaction  \
# 0  I will greet you when you arrive and show you ...
# 1                                                NaN
# 2  My family lives in the building but we are not...
# 3  We're always here for our guests.  We have an ...
# 4  I travel a lot for work so you may not see me ...
#
#                                          house_rules  thumbnail_url  \
# 0  1. Your booking is for ONE (1) person only. Yo...            NaN
# 1  Don't sit around all day watching T.V. Don't h...            NaN
# 2  This is a tiny apartment and is only appropria...            NaN
# 3                                                NaN            NaN
# 4  No smoking in the condo.  I only rent to adult...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/acf6b3c0-4...
# 1         NaN  https://a0.muscache.com/im/pictures/15019798/7...
# 2         NaN  https://a0.muscache.com/im/pictures/51073/16c8...
# 3         NaN  https://a0.muscache.com/im/pictures/37df1935-8...
# 4         NaN  https://a0.muscache.com/im/pictures/51944609/8...
#
#    xl_picture_url  host_id                                 host_url  \
# 0             NaN     2613   https://www.airbnb.com/users/show/2613
# 1             NaN     5775   https://www.airbnb.com/users/show/5775
# 2             NaN    17928  https://www.airbnb.com/users/show/17928
# 3             NaN    33004  https://www.airbnb.com/users/show/33004
# 4             NaN     2140   https://www.airbnb.com/users/show/2140
#
#           host_name  host_since                     host_location  \
# 0           Rebecca  2008-08-29  Chicago, Illinois, United States
# 1  Craig & Kathleen  2008-12-29  Chicago, Illinois, United States
# 2             Sarah  2009-05-19  Chicago, Illinois, United States
# 3       At Home Inn  2009-08-21  Chicago, Illinois, United States
# 4       Lois And Ed  2008-08-16   Aurora, Illinois, United States
#
#                                           host_about host_response_time  \
# 0  My 2 bdrm apartment is a 2nd floor walk-up in ...     within an hour
# 1  Incredibly creative(Kathleen) and stunningly a...     within an hour
# 2  We live in Chicago. We love to travel and see ...     within an hour
# 3  Hi, we're Bob and Liz Biddle, long time Chicag...     within an hour
# 4  Outgoing people who love people and exploring ...     within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 t
# 1               100%                   NaN                 t
# 2               100%                   NaN                 f
# 3                89%                   NaN                 f
# 4                93%                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/8bb47...
# 1  https://a0.muscache.com/im/users/5775/profile_...
# 2  https://a0.muscache.com/im/users/17928/profile...
# 3  https://a0.muscache.com/im/pictures/e23d4143-c...
# 4  https://a0.muscache.com/im/pictures/a8ba9bee-c...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/8bb47...          Hyde Park
# 1  https://a0.muscache.com/im/users/5775/profile_...     Little Village
# 2  https://a0.muscache.com/im/users/17928/profile...  Ukrainian Village
# 3  https://a0.muscache.com/im/pictures/e23d4143-c...           Old Town
# 4  https://a0.muscache.com/im/pictures/a8ba9bee-c...          Hyde Park
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  1.0                        1.0
# 2                  2.0                        2.0
# 3                 11.0                       11.0
# 4                  5.0                        5.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'manual_offline'...                    t
# 1               ['email', 'phone', 'reviews', 'kba']                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#   host_identity_verified                      street      neighbourhood  \
# 0                      t  Chicago, IL, United States          Hyde Park
# 1                      t  Chicago, IL, United States     Little Village
# 2                      f  Chicago, IL, United States  Ukrainian Village
# 3                      t  Chicago, IL, United States           Old Town
# 4                      t  Chicago, IL, United States          Hyde Park
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed     city state zipcode  \
# 0              Hyde Park                           NaN  Chicago    IL   60637
# 1         South Lawndale                           NaN  Chicago    IL   60608
# 2              West Town                           NaN  Chicago    IL   60622
# 3           Lincoln Park                           NaN  Chicago    IL   60614
# 4              Hyde Park                           NaN  Chicago    IL   60615
#
#     market smart_location country_code        country  latitude  longitude  \
# 0  Chicago    Chicago, IL           US  United States  41.78886  -87.58671
# 1  Chicago    Chicago, IL           US  United States  41.85495  -87.69696
# 2  Chicago    Chicago, IL           US  United States  41.90289  -87.68182
# 3  Chicago    Chicago, IL           US  United States  41.91769  -87.63788
# 4  Chicago    Chicago, IL           US  United States  41.79708  -87.59195
#
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 t   Condominium     Private room             1        1.0
# 1                 t     Apartment  Entire home/apt             7        1.0
# 2                 t     Apartment  Entire home/apt             2        1.0
# 3                 t     Apartment  Entire home/apt             4        1.0
# 4                 t     Apartment     Private room             2        1.0
#
#    bedrooms  beds  bed_type  \
# 0       1.0   1.0  Real Bed
# 1       3.0   4.0  Real Bed
# 2       1.0   1.0     Futon
# 3       1.0   2.0  Real Bed
# 4       1.0   1.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,Wifi,Kitchen,"Free street parking",Heating...          NaN   $50.00
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $117.00
# 2  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...          NaN   $80.00
# 3  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $150.00
# 4  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN   $35.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0      $350.00           NaN            $0.00       $15.00                1
# 1      $925.00           NaN            $0.00       $35.00                2
# 2      $600.00           NaN            $0.00        $0.00                1
# 3    $1,050.00     $3,400.00              NaN       $95.00                2
# 4      $235.00       $805.00          $200.00       $50.00                1
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0        $0.00               2              89                       2
# 1       $25.00               2              60                       2
# 2        $0.00               2              60                       2
# 3       $25.00               4              60                       4
# 4       $10.00               2             365                       2
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       2                      89                      89
# 1                       2                      60                      60
# 2                       2                      60                      60
# 3                       4                      60                      60
# 4                       2                     365                     365
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     2.0                    89.0      3 weeks ago
# 1                     2.0                    60.0        yesterday
# 2                     2.0                    60.0        yesterday
# 3                     4.0                    60.0       2 days ago
# 4                     2.0                   365.0        yesterday
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               15               39               61
# 1                t               10               25               46
# 2                t                7               23               38
# 3                t                2                3                9
# 4                t                7               37               61
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               316            2019-05-19                149
# 1               310            2019-05-19                368
# 2               309            2019-05-19                338
# 3               280            2019-05-19                 35
# 4               240            2019-05-19                 38
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                     31   2015-01-09  2019-05-17                 100.0
# 1                     23   2009-03-06  2019-05-05                  96.0
# 2                     51   2009-07-03  2019-05-05                  92.0
# 3                     15   2014-04-15  2019-05-15                  92.0
# 4                      9   2014-10-25  2019-04-12                  85.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                    10.0                       10.0                   10.0
# 2                    10.0                        9.0                   10.0
# 3                     9.0                        9.0                   10.0
# 4                     9.0                        8.0                    9.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                     9.0                  9.0
# 2                         10.0                    10.0                 10.0
# 3                          9.0                    10.0                  9.0
# 4                          9.0                    10.0                  9.0
#
#   requires_license                    license  \
# 0                t               R17000015609
# 1                t               R19000037538
# 2                t               R18000034991
# 3                t                    2079260
# 4                t  City registration pending
#
#                                   jurisdiction_names instant_bookable  \
# 0  {"Illinois State"," Cook County"," IL"," CHICA...                f
# 1  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 2  {"Illinois State"," Cook County"," IL"," CHICA...                f
# 3  {"Illinois State"," Cook County"," IL"," CHICA...                t
# 4  {"Illinois State"," Cook County"," IL"," CHICA...                t
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     moderate
# 2                        f                     moderate
# 3                        f  strict_14_with_grace_period
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               1
# 3                              11
# 4                               5
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
# 2                                            1
# 3                                           11
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             4
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               2.81
# 1                                            0               2.96
# 2                                            0               2.81
# 3                                            0               0.56
# 4                                            0               0.68

# %%
neighborhoods.head()
# Out:
#    neighbourhood_group   neighbourhood
# 0                  NaN     Albany Park
# 1                  NaN  Archer Heights
# 2                  NaN   Armour Square
# 3                  NaN         Ashburn
# 4                  NaN  Auburn Gresham

# %%
calendar.shape, reviews_1.shape, reviews_2.shape, listings.shape, listings_2.shape, neighborhoods.shape
# Out:
# ((2981670, 7), (306085, 2), (306085, 6), (8169, 16), (8169, 106), (77, 2))

# %%
listings_2['id'].nunique()
# Out:
# 8169

# %%
listings_2.nunique()
# Out:
# id                                              8169
# listing_url                                     8169
# scrape_id                                          1
# last_scraped                                       1
# name                                            8035
# summary                                         7097
# space                                           5701
# description                                     7486
# experiences_offered                                1
# neighborhood_overview                           4600
# notes                                           3612
# transit                                         4787
# access                                          4585
# interaction                                     4267
# house_rules                                     4449
# thumbnail_url                                      0
# medium_url                                         0
# picture_url                                     7904
# xl_picture_url                                     0
# host_id                                         4615
# host_url                                        4615
# host_name                                       2226
# host_since                                      2247
# host_location                                    247
# host_about                                      2936
# host_response_time                                 4
# host_response_rate                                54
# host_acceptance_rate                               0
# host_is_superhost                                  2
# host_thumbnail_url                              4603
# host_picture_url                                4603
# host_neighbourhood                               117
# host_listings_count                               55
# host_total_listings_count                         55
# host_verifications                               265
# host_has_profile_pic                               2
# host_identity_verified                             2
# street                                            20
# neighbourhood                                     87
# neighbourhood_cleansed                            74
# neighbourhood_group_cleansed                       0
# city                                              16
# state                                              3
# zipcode                                           75
# market                                             3
# smart_location                                    20
# country_code                                       1
# country                                            1
# latitude                                        6474
# longitude                                       5989
# is_location_exact                                  2
# property_type                                     27
# room_type                                          3
# accommodates                                      20
# bathrooms                                         19
# bedrooms                                          15
# beds                                              24
# bed_type                                           5
# amenities                                       7306
# square_feet                                       34
# price                                            432
# weekly_price                                     211
# monthly_price                                    220
# security_deposit                                  73
# cleaning_fee                                     172
# guests_included                                   17
# extra_people                                      62
# minimum_nights                                    53
# maximum_nights                                   136
# minimum_minimum_nights                            54
# maximum_minimum_nights                            74
# minimum_maximum_nights                           136
# maximum_maximum_nights                           146
# minimum_nights_avg_ntm                           180
# maximum_nights_avg_ntm                           225
# calendar_updated                                  48
# has_availability                                   1
# availability_30                                   31
# availability_60                                   61
# availability_90                                   91
# availability_365                                 366
# calendar_last_scraped                              1
# number_of_reviews                                319
# number_of_reviews_ltm                            131
# first_review                                    1607
# last_review                                      663
# review_scores_rating                              41
# review_scores_accuracy                             8
# review_scores_cleanliness                          9
# review_scores_checkin                              8
# review_scores_communication                        8
# review_scores_location                             8
# review_scores_value                                8
# requires_license                                   2
# license                                         3925
# jurisdiction_names                                 7
# instant_bookable                                   2
# is_business_travel_ready                           1
# cancellation_policy                                6
# require_guest_profile_picture                      2
# require_guest_phone_verification                   2
# calculated_host_listings_count                    38
# calculated_host_listings_count_entire_homes       33
# calculated_host_listings_count_private_rooms      20
# calculated_host_listings_count_shared_rooms       14
# reviews_per_month                                822
# dtype: int64

# %%
listings_2['reviews_per_month'].value_counts()
# Out:
# 1.00     166
# 2.00      79
# 3.00      54
# 0.09      44
# 0.05      40
# 0.10      40
# 0.14      38
# 0.29      37
# 0.13      35
# 0.06      34
# 0.22      34
# 0.17      34
# 0.27      34
# 0.32      34
# 0.12      33
# 0.11      33
# 0.26      33
# 0.38      31
# 0.39      31
# 0.19      31
# 0.88      30
# 0.49      30
# 0.34      30
# 0.28      30
# 0.83      30
# 0.81      30
# 0.15      29
# 0.33      29
# 0.47      28
# 0.08      28
# 0.16      28
# 0.61      28
# 0.18      28
# 0.43      27
# 0.25      27
# 4.00      27
# 0.69      26
# 0.58      26
# 0.44      26
# 0.24      26
# 0.41      26
# 0.36      25
# 0.85      25
# 0.31      25
# 3.10      11
# 2.20      11
# 2.76      11
# 1.31      11
# 3.85      11
# 0.66      11
# 2.40      11
# 3.40      11
# 1.43      11
# 2.69      11
# 3.26      11
# 1.33      11
#         ...
# 7.18       3
# 5.34       3
# 7.62       2
# 6.14       2
# 3.06       2
# 6.08       2
# 7.76       2
# 7.39       2
# 7.03       2
# 5.91       2
# 7.13       2
# 4.49       2
# 8.31       2
# 5.02       2
# 6.69       2
# 7.22       2
# 5.11       2
# 8.90       2
# 6.94       2
# 6.09       2
# 8.20       2
# 5.72       2
# 8.34       2
# 5.47       2
# 7.61       2
# 7.55       2
# 6.24       2
# 7.40       2
# 6.53       2
# 5.21       2
# 5.70       2
# 7.83       2
# 4.73       2
# 7.58       2
# 5.68       2
# 6.82       2
# 7.00       2
# 6.66       2
# 7.96       2
# 6.45       2
# 7.23       2
# 5.42       2
# 5.60       2
# 7.07       2
# 5.07       2
# 4.52       2
# 10.74      2
# 7.06       2
# 6.34       2
# 5.26       2
# 7.48       2
# 6.77       2
# 7.38       2
# 7.70       2
# 5.82       2
# 5.64       2
# 6.96       2
# 7.78       2
# 4.61       2
# 8.18       2
# 5.80       2
# 6.20       2
# 10.45      2
# 6.07       2
# 6.55       2
# 6.26       2
# 5.93       2
# 6.91       2
# 4.47       2
# 9.33       2
# 6.58       2
# 6.13       2
# 5.58       2
# 6.05       2
# 9.17       2
# 5.28       2
# 5.87       2
# 7.86       2
# 5.32       2
# 7.27       2
# 7.08       2
# 5.89       2
# 6.65       2
# 5.55       2
# 5.99       2
# 5.81       2
# 7.99       2
# 4.43       2
# 4.68       2
# 6.36       2
# 6.42       2
# 5.18       2
# 6.51       2
# 5.98       2
# 8.41       2
# 4.79       2
# 8.64       2
# 7.34       2
# 7.74       2
# 7.69       2
# 5.10       2
# 6.75       2
# 5.53       2
# 5.67       2
# 8.11       2
# 4.64       2
# 8.76       1
# 9.85       1
# 6.28       1
# 8.40       1
# 7.11       1
# 9.97       1
# 11.47      1
# 9.09       1
# 7.71       1
# 7.31       1
# 7.19       1
# 12.41      1
# 10.52      1
# 7.29       1
# 7.98       1
# 7.46       1
# 7.45       1
# 8.96       1
# 6.73       1
# 6.92       1
# 9.37       1
# 7.97       1
# 7.44       1
# 7.25       1
# 14.48      1
# 10.41      1
# 9.00       1
# 9.99       1
# 6.79       1
# 5.50       1
# 6.40       1
# 6.19       1
# 8.59       1
# 6.06       1
# 8.80       1
# 6.60       1
# 9.14       1
# 7.59       1
# 7.20       1
# 8.39       1
# 6.63       1
# 6.11       1
# 8.87       1
# 6.49       1
# 7.05       1
# 6.64       1
# 9.78       1
# 8.91       1
# 6.33       1
# 8.29       1
# 9.01       1
# 9.89       1
# 8.79       1
# 8.99       1
# 8.08       1
# 7.12       1
# 6.54       1
# 4.99       1
# 7.14       1
# 6.16       1
# 7.89       1
# 9.66       1
# 9.96       1
# 7.79       1
# 6.88       1
# 10.65      1
# 7.21       1
# 6.57       1
# 10.30      1
# 8.70       1
# 8.55       1
# 5.78       1
# 5.05       1
# 6.76       1
# 9.67       1
# 3.91       1
# 6.86       1
# 9.55       1
# 8.67       1
# 8.19       1
# 7.60       1
# 6.95       1
# 8.48       1
# 9.34       1
# 8.07       1
# 5.92       1
# 8.17       1
# 8.28       1
# 6.74       1
# 6.83       1
# 9.02       1
# 10.15      1
# 5.66       1
# 11.40      1
# 10.44      1
# 8.06       1
# 8.56       1
# 6.90       1
# 7.80       1
# 5.65       1
# 4.31       1
# 11.17      1
# 10.03      1
# 8.46       1
# 9.24       1
# 7.54       1
# 8.95       1
# 8.53       1
# 8.93       1
# 6.01       1
# 6.59       1
# 9.03       1
# 10.06      1
# 6.39       1
# 9.72       1
# 5.62       1
# 6.46       1
# 7.41       1
# 10.69      1
# 6.78       1
# 4.56       1
# 7.57       1
# 10.19      1
# 7.36       1
# 4.54       1
# 7.43       1
# 12.34      1
# 7.47       1
# 6.84       1
# 10.04      1
# 4.69       1
# 14.83      1
# 10.32      1
# 6.21       1
# 6.03       1
# 6.35       1
# 7.30       1
# 10.60      1
# 4.90       1
# 8.27       1
# 11.62      1
# 8.66       1
# 11.07      1
# 8.75       1
# Name: reviews_per_month, Length: 822, dtype: int64

# %%
df = listings_2.drop([
'id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space', 'description', 'experiences_offered',
'neighborhood_overview', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url',
'picture_url', 'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
'host_acceptance_rate', 'host_thumbnail_url', 'host_picture_url', 'host_picture_url', 'street', 'state', 'market',
'smart_location', 'country', 'square_feet', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60',
'availability_90', 'availability_365', 'calendar_last_scraped', 'first_review', 'last_review', 'license', 'jurisdiction_names',
'is_business_travel_ready', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes',
'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'host_verifications', 'host_has_profile_pic',
'host_identity_verified', 'host_listings_count', 'host_total_listings_count', 'host_response_time', 'host_response_rate',
'host_is_superhost', 'neighbourhood_group_cleansed', 'city', 'country_code', 'is_location_exact', 'monthly_price', 'minimum_nights',
'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights',
'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'requires_license', 'require_guest_profile_picture', 'require_guest_phone_verification',
'weekly_price', 'host_neighbourhood'], axis=1)

# %%
df.head()
# Out:
#        neighbourhood neighbourhood_cleansed zipcode  latitude  longitude  \
# 0          Hyde Park              Hyde Park   60637  41.78886  -87.58671
# 1     Little Village         South Lawndale   60608  41.85495  -87.69696
# 2  Ukrainian Village              West Town   60622  41.90289  -87.68182
# 3           Old Town           Lincoln Park   60614  41.91769  -87.63788
# 4          Hyde Park              Hyde Park   60615  41.79708  -87.59195
#
#   property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0   Condominium     Private room             1        1.0       1.0   1.0
# 1     Apartment  Entire home/apt             7        1.0       3.0   4.0
# 2     Apartment  Entire home/apt             2        1.0       1.0   1.0
# 3     Apartment  Entire home/apt             4        1.0       1.0   2.0
# 4     Apartment     Private room             2        1.0       1.0   1.0
#
#    bed_type                                          amenities    price  \
# 0  Real Bed  {TV,Wifi,Kitchen,"Free street parking",Heating...   $50.00
# 1  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $117.00
# 2     Futon  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...   $80.00
# 3  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $150.00
# 4  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...   $35.00
#
#   security_deposit cleaning_fee  guests_included extra_people  \
# 0            $0.00       $15.00                1        $0.00
# 1            $0.00       $35.00                2       $25.00
# 2            $0.00        $0.00                1        $0.00
# 3              NaN       $95.00                2       $25.00
# 4          $200.00       $50.00                1       $10.00
#
#    number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# 0                149                     31                 100.0
# 1                368                     23                  96.0
# 2                338                     51                  92.0
# 3                 35                     15                  92.0
# 4                 38                      9                  85.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                    10.0                       10.0                   10.0
# 2                    10.0                        9.0                   10.0
# 3                     9.0                        9.0                   10.0
# 4                     9.0                        8.0                    9.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                     9.0                  9.0
# 2                         10.0                    10.0                 10.0
# 3                          9.0                    10.0                  9.0
# 4                          9.0                    10.0                  9.0
#
#   instant_bookable          cancellation_policy  reviews_per_month
# 0                f  strict_14_with_grace_period               2.81
# 1                t                     moderate               2.96
# 2                f                     moderate               2.81
# 3                t  strict_14_with_grace_period               0.56
# 4                t                     moderate               0.68

# %%
df.columns
# Out:
# Index(['neighbourhood', 'neighbourhood_cleansed', 'zipcode', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bedrooms', 'beds', 'bed_type', 'amenities', 'price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'number_of_reviews', 'number_of_reviews_ltm', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'instant_bookable',
#        'cancellation_policy', 'reviews_per_month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8169 entries, 0 to 8168
# Data columns (total 30 columns):
# neighbourhood                  8169 non-null object
# neighbourhood_cleansed         8169 non-null object
# zipcode                        8143 non-null object
# latitude                       8169 non-null float64
# longitude                      8169 non-null float64
# property_type                  8169 non-null object
# room_type                      8169 non-null object
# accommodates                   8169 non-null int64
# bathrooms                      8164 non-null float64
# bedrooms                       8168 non-null float64
# beds                           8167 non-null float64
# bed_type                       8169 non-null object
# amenities                      8169 non-null object
# price                          8169 non-null object
# security_deposit               5990 non-null object
# cleaning_fee                   7089 non-null object
# guests_included                8169 non-null int64
# extra_people                   8169 non-null object
# number_of_reviews              8169 non-null int64
# number_of_reviews_ltm          8169 non-null int64
# review_scores_rating           7018 non-null float64
# review_scores_accuracy         7018 non-null float64
# review_scores_cleanliness      7018 non-null float64
# review_scores_checkin          7016 non-null float64
# review_scores_communication    7016 non-null float64
# review_scores_location         7016 non-null float64
# review_scores_value            7016 non-null float64
# instant_bookable               8169 non-null object
# cancellation_policy            8169 non-null object
# reviews_per_month              7084 non-null float64
# dtypes: float64(13), int64(4), object(13)
# memory usage: 1.9+ MB

# %%
df.nunique()
# Out:
# neighbourhood                    87
# neighbourhood_cleansed           74
# zipcode                          75
# latitude                       6474
# longitude                      5989
# property_type                    27
# room_type                         3
# accommodates                     20
# bathrooms                        19
# bedrooms                         15
# beds                             24
# bed_type                          5
# amenities                      7306
# price                           432
# security_deposit                 73
# cleaning_fee                    172
# guests_included                  17
# extra_people                     62
# number_of_reviews               319
# number_of_reviews_ltm           131
# review_scores_rating             41
# review_scores_accuracy            8
# review_scores_cleanliness         9
# review_scores_checkin             8
# review_scores_communication       8
# review_scores_location            8
# review_scores_value               8
# instant_bookable                  2
# cancellation_policy               6
# reviews_per_month               822
# dtype: int64

# %%
df['number_of_reviews']
# Out:
# 0       149
# 1       368
# 2       338
# 3        35
# 4        38
# 5         9
# 6         4
# 7         9
# 8        37
# 9       178
# 10       44
# 11       47
# 12      242
# 13      467
# 14       51
# 15      233
# 16      243
# 17      252
# 18       58
# 19      146
# 20       54
# 21      134
# 22      142
# 23       34
# 24       19
# 25       14
# 26       36
# 27       58
# 28       79
# 29       21
# 30       58
